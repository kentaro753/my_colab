# %%
import math

# %%
#Câu 1
N=int(input("Nhập N: "))
def giaiThua(N):
    if N == 0:
        return 1
    return N * giaiThua(N - 1)
print (giaiThua(N))
# Out:
# Nhập N: 3
# 6

# %%
#Câu 2
N=int(input("Nhập N: "))
if N % 2 == 0:
  print("N là số chẵn")
else : print("N là số lẻ")
# Out:
# Nhập N: 3
# N là số lẽ

# %%
#Câu 3
N=int(input("Nhập N: "))
i=1;
while i<=N:
    if i % 7==0 and i % 5 != 0 : print(i)
    i+=1
# Out:
# Nhập N: 100
# 7
# 14
# 21
# 28
# 42
# 49
# 56
# 63
# 77
# 84
# 91
# 98

# %%
#Câu 4
def Ptbac2(a, b, c):
    if (a == 0):
        if (b == 0):
            print ("Phương trình vô nghiệm!")
        else:
            print ("Phương trình có một nghiệm: x = ", + (-c / b))
        return
    delta = b * b - 4 * a * c
    if (delta > 0):
        x1 = (float)((-b + math.sqrt(delta)) / (2 * a))
        x2 = (float)((-b - math.sqrt(delta)) / (2 * a))
        print ("Phương trình có 2 nghiệm là: x1 = ", x1, " và x2 = ", x2)
    elif (delta == 0):
        x1 = (-b / (2 * a))
        print("Phương trình có nghiệm kép: x1 = x2 = ", x1)
    else:
        print("Phương trình vô nghiệm!")
a = float(input("Nhập hệ số bậc 2, a = "))
b = float(input("Nhập hệ số bậc 1, b = "))
c = float(input("Nhập hằng số tự do, c = "))

Ptbac2(a, b, c)
# Out:
# Nhập hệ số bậc 2, a = 1
# Nhập hệ số bậc 1, b = -3
# Nhập hằng số tự do, c = 2
# Phương trình có 2 nghiệm là: x1 =  2.0  và x2 =  1.0

# %%
#Câu 5
def isPrime(n):
    if n==2 or n==3: return True
    if n%2==0 or n<2: return False
    for i in range(3, int(n**0.5)+1, 2):  
        if n%i==0:
            return False    

    return True
n = int(input('Nhập N = ')) 
print('Các số nguyên tố từ 1 tới ', n, ' là:') 
for i in range(2, n + 1): 
  if isPrime(i): 
    print(i)
# Out:
# Nhập N = 20
# Các số nguyên tố từ 1 tới  20  là:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %%
#Câu 6
r = int(input('Nhập bán kính r = ')) 
S=3.14 * r * r
C= 2 * 3.14 * r
print("Diện tích hình tròn S = ",S)
print("Chu vi hình tròn C = ",C)
# Out:
# Nhập bán kính r = 5
# Diện tích hình tròn S =  78.5
# Chu vi hình tròn C =  31.400000000000002

# %%
#Câu 7
F = int(input("Nhập độ F:"))
C = (5/9)*(F-32)
print("Độ C là",C)
# Out:
# Nhập độ F:127
# Độ C là 52.77777777777778

# %%
#Câu 8
n = int(input("Nhập N: "))
if( 1<= n<= 100):
    print("OK")
# Out:
# Nhập N: 300

# %%
#Câu 9
n = int(input("Nhập N: "))
if( 1<= n<= 100):
    print("OK")
else : print("số không nằm trong khoảng 1 – 100")
# Out:
# Nhập N: 200
# số không nằm trong khoảng 1 – 100

# %%
#Câu 10
s=input("Nhập tên một ngày trong tuần: ")
if s=="Thứ Hai" : print("Monday")
if s=="Thứ Ba" : print("Tuesday")
if s=="Thứ Tư" : print("Wednesday")
if s=="Thứ Năm" : print("Thursday")
if s=="Thứ Sáu" : print("Friday")
if s=="Thứ Bảy" : print("Saturday")
if s=="Chủ Nhật" : print("Sunday")
# Out:
# Nhập tên một ngày trong tuần: Thứ Năm
# Thursday

# %%
#Câu 11
a = int(input("Nhập cạnh a: "))
b = int(input("Nhập cạnh b: "))
c = int(input("Nhập cạnh c: "))
d = int(input("Nhập cạnh d: "))
Cv = a+b+c+d
S = a*b
if a == c and b == d :
  if a == b : 
    print("Hình vuông \nChu vi là :",Cv,"\nDiện tích là:",S)
  else :print("Hình chữ nhật \nChu vi là :",Cv,"\nDiện tích là:",S)
else :print("Chu vi hình tứ giác là :",Cv)
# Out:
# Nhập cạnh a: 2
# Nhập cạnh b: 5
# Nhập cạnh c: 2
# Nhập cạnh d: 5
# Hình chữ nhật
# Chu vi là : 14
# Diện tích là: 10

# %%
#Câu 12
S=int(input("Quảng đường là(km): ")) 
v=int(input("Vận tốc là(km/h): ")) 
t=S/v 
h=7.5+t 
m=(h-int(h))*60  
h=math.floor(h) 
print("thời gian để đến nơi là: ",h,"giờ",round(m),"phút")
# Out:
# Quảng đường là(km): 10
# Vận tốc là(km/h): 5
# thời gian để đến nơi là:  9 giờ 30 phút
