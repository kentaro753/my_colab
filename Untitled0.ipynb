# %%
print("Phạm Nguyễn Hữu Toàn")
print("ae-Karina 30 roll")
print(10 + 1)
print("10 + 1")
print("Phạm \nNguyễn Hữu \nToàn")
print("Phạm", end=' ')
print("Nguyễn Hữu", end=' ')
print("Toàn")
# Out:
# Phạm Nguyễn Hữu Toàn
# ae-Karina 30 roll
# 11
# 10 + 1
# Phạm
# Nguyễn Hữu
# Toàn
# Phạm Nguyễn Hữu Toàn

# %%
print("Quanh năm buôn bán ở mom sông \nNuôi đủ năm con với 1 chồng \n\tLặn lội thân cò khi quãng vắng \n\tEo sèo mặt nước buổi \"đò đông\" \nMột duyên hai nợ âu đành phận  \nNăm nắng mười mưa há chẳng công")
print("ooooooooo") 
print("""Quanh năm buôn bán ở mom sông 
Nuôi đủ năm con với 1 chồng 
    Lặn lội thân cò khi quãng vắng 
    Eo sèo mặt nước buổi "đò đông" 
Một duyên hai nợ âu đành phận  
Năm nắng mười mưa há chẳng công""")
# Out:
# Quanh năm buôn bán ở mom sông
# Nuôi đủ năm con với 1 chồng
# 	Lặn lội thân cò khi quãng vắng
# 	Eo sèo mặt nước buổi "đò đông"
# Một duyên hai nợ âu đành phận
# Năm nắng mười mưa há chẳng công
# ooooooooo
# Quanh năm buôn bán ở mom sông
# Nuôi đủ năm con với 1 chồng
#     Lặn lội thân cò khi quãng vắng
#     Eo sèo mặt nước buổi "đò đông"
# Một duyên hai nợ âu đành phận
# Năm nắng mười mưa há chẳng công
