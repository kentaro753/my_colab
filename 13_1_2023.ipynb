# %%
print("Thủ Dầu Một University")
def tong():
  print("Tổng của 2 + 3: ",2 + 3)

def tonghaiso(a,b):
  print("Tổng 2 số là: ",a + b)

tong()
tonghaiso(3,4)
# Out:
# Thủ Dầu Một University
# Tổng của 2 + 3:  5
# Tổng 2 số là:  7

# %%
def tong(a=1,b=2):
  return a+b

print("không truyền tham số: ",tong())
print("Có truyền tham số: ",tong(4,5))
# Out:
# không truyền tham số:  3
# Có truyền tham số:  9

# %%
a = "biến ngoài hàm"
def hi():
  a = "biến trong hàm"
  print(a)
hi()
print(a)
# Out:
# biến trong hàm
# biến ngoài hàm

# %%
a = "biến ngoài hàm"
def hi():
  global a
  a = "biến trong hàm"
  print(a)
hi()
print(a)
# Out:
# biến trong hàm
# biến trong hàm

# %%
def  baitap(*a):
  tmp = 0
  #duyet cac tham so
  for i in a: tmp += i
  return tmp
def  baitap1():
  global a
  a = "chúng em chào TDMU"
  print (a)
kq = baitap(10,20,30)
print (kq)
baitap1()
# Out:
# 60
# chúng em chào TDMU
