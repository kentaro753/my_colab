# %%
#1
print("Nhập tên: ")
s=input()
print(s)
# Out:
# Nhập tên:
# toan
# toan

# %%
#2
s=input("Nhập tên:")
print(s)
# Out:
# Nhập tên:toan
# toan

# %%
s=input('Nhập tên: ')
print(s)
a=int(input('Tuổi: '))
print(s,"Số năm còn lại để được 100 tuổi là: ",100 - a)
# Out:
# Nhập tên: toan
# toan
# Tuổi: 20
# toan Số năm còn lại để được 100 tuổi là:  80

# %%
s=input('Nhập tên: ')
a=int(input('Tuổi: '))
m=int(input('Điểm: '))
if(m>=5): print(s,'đã qua môn')
else: print(s,'đã rớt môn')
# Out:
# Nhập tên: toàn
# Tuổi: 20
# Điểm: 6
# toàn đã qua môn

# %%
x = range(10,1,-2)
for n in x:
  print(n)
# Out:
# 10
# 8
# 6
# 4
# 2
